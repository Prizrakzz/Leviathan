# %% [markdown]
# # Silver feature-engineering readiness index
#
# Answer-first campaign report over the complete current Silver registry. It summarizes readiness, blockers, existing feature coverage, and review-only feature opportunities. It contains no target correlations and reads no old Gold or model-ready data.

# %%
_PAYLOAD_B64 = "..."
import base64, json, zlib
import pandas as pd
from IPython import get_ipython

_IPYTHON = get_ipython()
if _IPYTHON is not None:
    _IPYTHON.run_line_magic("matplotlib", "inline")

import matplotlib.pyplot as plt
from IPython.display import Markdown, display
P = json.loads(zlib.decompress(base64.b64decode(_PAYLOAD_B64)).decode("utf-8"))
READINESS, CATALOG, SPECS, PROVENANCE = P["readiness"], P["catalog"], P["specs"], P["provenance"]
ROWS = pd.DataFrame(READINESS["rows"])
pd.set_option("display.max_rows", 20); pd.set_option("display.max_colwidth", 100)
plt.rcParams.update({"figure.dpi": 120, "savefig.dpi": 120, "axes.grid": True, "grid.alpha": .2})

# %% [markdown]
# ## Campaign decision capsule
#
# The campaign decision is complete only when every current Silver table has a validated dossier.

# %%
expected = READINESS["expected_tables"]
actual = sorted(ROWS.table_name.tolist())
complete = actual == sorted(expected) and len(actual) == 42
capsule = pd.DataFrame([{
    "dossiers": len(actual), "expected": len(expected), "complete": complete,
    "ready_for_feature_ideation": int((ROWS.disposition == "ready_for_feature_ideation").sum()),
    "needs_contract_or_data_fix": int((ROWS.disposition == "needs_contract_or_data_fix").sum()),
    "diagnostic_only": int((ROWS.disposition == "diagnostic_only").sum()),
    "blocked": int((ROWS.disposition == "blocked").sum()),
    "excluded_leakage": int((ROWS.disposition == "excluded_leakage").sum()),
    "candidate_count": int(ROWS.candidate_count.sum()),
    "prototype_ready_candidate_count": int(ROWS.get("prototype_ready_candidate_count", pd.Series(dtype=int)).sum()),
    "candidate_prerequisite_count": int(ROWS.get("candidate_prerequisite_count", pd.Series(dtype=int)).sum()),
    "campaign_id": PROVENANCE.get("campaign_id"), "analysis_scope": "source-only Silver",
    "exactness": "exact",
}])
display(capsule)
assert complete, {"missing": sorted(set(expected)-set(actual)), "extra": sorted(set(actual)-set(expected))}
display(Markdown("**Decision.** The readiness index contains exactly 42/42 current Silver dossiers. Candidate promotion remains a separate reviewed action."))
# Out:
#    dossiers  expected  complete  ready_for_feature_ideation  \
# 0        42        42      True                           2
#
#    needs_contract_or_data_fix  diagnostic_only  blocked  excluded_leakage  \
# 0                          31                1        7                 1
#
#    candidate_count  prototype_ready_candidate_count  \
# 0              442                               11
#
#    candidate_prerequisite_count                          campaign_id  \
# 0                           421  readerfirst-final-20260718-a176abf1
#
#        analysis_scope exactness
# 0  source-only Silver     exact
# **Decision.** The readiness index contains exactly 42/42 current Silver dossiers. Candidate promotion remains a separate reviewed action.

# %% [markdown]
# ## Registry and dossier coverage
#
# Exact registry-set equality prevents stale, missing, extra, Gold, or cross-campaign artifacts from being summarized.

# %%
display(ROWS.sort_values("table_name"))
display(pd.DataFrame([{"field": k, "value": json.dumps(v, sort_keys=True) if isinstance(v, (dict,list)) else v, "exactness": "exact"} for k,v in sorted(PROVENANCE.items())]))
assert READINESS["analysis_scope"]["gold_contracts_included"] == 0
# Out:
#    analysis_exactness  \
# 0               exact
# 1             sampled
# 2               exact
# 3               exact
# 4               exact
# ..                ...
# 37              exact
# 38              exact
# 39              exact
# 40              exact
# 41              exact
#
#                                                               analyzer_routes  \
# 0                                      [wide_panel, annual_or_seasonal_panel]
# 1                  [long_metric_value, time_series, annual_or_seasonal_panel]
# 2                                                                [wide_panel]
# 3                                                                [wide_panel]
# 4                  [long_metric_value, time_series, annual_or_seasonal_panel]
# ..                                                                        ...
# 37                           [wide_panel, progressive_curve, derived_lineage]
# 38                                              [wide_panel, derived_lineage]
# 39                                     [wide_panel, annual_or_seasonal_panel]
# 40  [wide_panel, annual_or_seasonal_panel, vintage_revision, derived_lineage]
# 41            [long_metric_value, annual_or_seasonal_panel, vintage_revision]
#
#     blocker_count  candidate_count  candidate_prerequisite_count  \
# 0               0               10                            10
# 1               0                5                             5
# 2               0                4                             4
# 3               0               16                            16
# 4               0                4                             4
# ..            ...              ...                           ...
# 37              2                0                             0
# 38              2                0                             0
# 39              2                0                             0
# 40              0                4                             3
# 41              0                6                             4
#
#                    disposition  finding_count  \
# 0   needs_contract_or_data_fix              2
# 1   needs_contract_or_data_fix              2
# 2   needs_contract_or_data_fix              2
# 3   needs_contract_or_data_fix              2
# 4   needs_contract_or_data_fix              3
# ..                         ...            ...
# 37                     blocked              4
# 38                     blocked              4
# 39                     blocked              3
# 40  needs_contract_or_data_fix              1
# 41  needs_contract_or_data_fix              1
#
#                                                                                              pit_status  \
# 0                                         {'knowledge_semantics': None, 'temporal_columns': ['season']}
# 1                    {'knowledge_semantics': None, 'temporal_columns': ['date', 'ingest_date', 'year']}
# 2                                     {'knowledge_semantics': None, 'temporal_columns': ['safra_year']}
# 3                                    {'knowledge_semantics': None, 'temporal_columns': ['report_date']}
# 4                    {'knowledge_semantics': None, 'temporal_columns': ['date', 'ingest_date', 'year']}
# ..                                                                                                  ...
# 37  {'knowledge_semantics': None, 'temporal_columns': ['fortnight_date', 'harvest_year', 'source_pos...
# 38  {'knowledge_semantics': None, 'temporal_columns': ['harvest_year', 'month_date', 'month_label', ...
# 39  {'knowledge_semantics': None, 'temporal_columns': ['marketing_year', 'month_abbr', 'release_mont...
# 40  {'knowledge_semantics': 'year_month', 'temporal_columns': ['marketing_year', 'month_abbr', 'prio...
# 41  {'knowledge_semantics': 'vintage', 'temporal_columns': ['marketing_year', 'marketing_year_end_da...
#
#     prototype_ready_candidate_count  row_count  source_total_rows  \
# 0                                 0         27               27.0
# 1                                 0    1000000          6496437.0
# 2                                 0        928              928.0
# 3                                 0      10806            10806.0
# 4                                 0    4086648          4086648.0
# ..                              ...        ...                ...
# 37                                0         86               86.0
# 38                                0         58               58.0
# 39                                0      96410            96410.0
# 40                                0      96410            96410.0
# 41                                0     682696           682696.0
#
#                             table_name
# 0            silver_ams_cotton_quality
# 1                        silver_chirps
# 2                  silver_conab_coffee
# 3                           silver_cot
# 4                      silver_cpc_soil
# ..                                 ...
# 37           silver_unica_corn_ethanol
# 38  silver_unica_monthly_ethanol_sales
# 39                  silver_wap_table01
# 40        silver_wap_table01_revisions
# 41                        silver_wasde
#
# [42 rows x 12 columns]
#                       field  \
# 0             assembly_mode
# 1               campaign_id
# 2            dossier_sha256
# 3         eda_config_sha256
# 4         eda_source_sha256
# 5                   git_sha
# 6  icco_reference_exception
# 7              image_digest
# 8           registry_sha256
# 9    repository_assembly_id
#
#                                                                                                  value  \
# 0                                                                             local_offline_repository
# 1                                                                  readerfirst-final-20260718-a176abf1
# 2  {"silver_ams_cotton_quality": "3c7ef74cbeab352d15dfaeeef9ecd99f0da070019b142bfde0af64a091cc9fc4"...
# 3                                     b37062169af7e58b8b7c0bd26cc3d34834704f2901c8bbae8f4977c2f14e9506
# 4                                     a176abf1a0cfda3dd07a0a1c9090b3749c81711690fa773da298541421cb9336
# 5                                                             e6146c826dbcd927127104b4bfcb9bb526ddf6b1
# 6  {"campaign_identity_required": false, "embedded_frame_sha256": "00f45c9aeffe65f5fd6f5eef3360a698...
# 7                              sha256:e9563290bdc62d3216841dfb190b59ef709ac5c5d2e4fc0b894c72de5548bed1
# 8                                     750ab7cbff35caccea4f9a12fdfe5c06a66a121450ffa1aff8215e075b9c3d5e
# 9                              sha256:b6fd1c68ea210d9b27a4d9dce0c54e5b6502b0135f807ff61bb9365c6ca073f9
#
#   exactness
# 0     exact
# 1     exact
# 2     exact
# 3     exact
# 4     exact
# 5     exact
# 6     exact
# 7     exact
# 8     exact
# 9     exact

# %% [markdown]
# ## Readiness and blockers
#
# Disposition and blocker distributions show where contract/data work is required before prototyping.

# %%
counts = ROWS.disposition.value_counts().sort_index()
ax = counts.plot.bar(color="#356AA0", figsize=(8, 3.5), legend=False)
ax.set_title(f"Silver readiness dispositions — n={len(ROWS)} dossiers — exact")
ax.set_ylabel("Tables"); plt.xticks(rotation=35, ha="right"); plt.show()
display(ROWS.loc[ROWS.blocker_count.gt(0), ["table_name","disposition","analysis_exactness","blocker_count","finding_count","candidate_count"]].sort_values(["blocker_count","table_name"], ascending=[False,True]))
# Out:
#                               table_name       disposition analysis_exactness  \
# 18                    silver_mpob_annual           blocked              exact
# 35  silver_unica_biweekly_release_series           blocked              exact
# 37             silver_unica_corn_ethanol           blocked              exact
# 38    silver_unica_monthly_ethanol_sales           blocked              exact
# 39                    silver_wap_table01           blocked              exact
# 15              silver_model_predictions  excluded_leakage              exact
# 31                      silver_sagis_cec           blocked              exact
# 36  silver_unica_biweekly_season_history           blocked              exact
#
#     blocker_count  finding_count  candidate_count
# 18              2              4                0
# 35              2              5                0
# 37              2              4                0
# 38              2              4                0
# 39              2              3                0
# 15              1              1                0
# 31              1              3                0
# 36              1              4                0

# %% [markdown]
# ## Existing feature coverage
#
# Existing source keys and table-level feature-family references show current coverage without claiming unverified candidate or column parity.

# %%
coverage = pd.DataFrame([{"table_name": name,
                          "source_keys": spec.get("source_keys", []),
                          "existing_feature_families": spec.get("existing_feature_families", []),
                          "column_coverage_status": spec.get("existing_feature_coverage", {}).get("column_coverage_status", "not_assessed"),
                          "candidate_classification_verified": spec.get("existing_feature_coverage", {}).get("candidate_classification_verified", False),
                          "feature_disposition": spec.get("feature_disposition")}
                         for name, spec in sorted(SPECS.items())])
coverage["existing_family_count"] = coverage.existing_feature_families.map(len)
coverage["exactness"] = "exact"
display(coverage)
ax = coverage.sort_values(["existing_family_count","table_name"]).tail(20).plot.barh(
    x="table_name", y="existing_family_count", color="#356AA0", legend=False, figsize=(9,6))
ax.set_title(
    f"Table-level feature-family references — n={len(coverage)} Silver sources; "
    "top 20 shown — exact"
)
ax.set_xlabel("Mapped feature families"); plt.show()
# Out:
#                             table_name           source_keys  \
# 0            silver_ams_cotton_quality  [ams_cotton_quality]
# 1                        silver_chirps      [weather:chirps]
# 2                  silver_conab_coffee               [conab]
# 3                           silver_cot                 [cot]
# 4                      silver_cpc_soil    [weather:cpc_soil]
# ..                                 ...                   ...
# 37           silver_unica_corn_ethanol                    []
# 38  silver_unica_monthly_ethanol_sales                    []
# 39                  silver_wap_table01                    []
# 40        silver_wap_table01_revisions       [wap_revisions]
# 41                        silver_wasde               [wasde]
#
#                               existing_feature_families  \
# 0                                  [ams_cotton_quality]
# 1   [drought_z, inseason_weather_dense, stage_precip_z]
# 2                           [conab_production_revision]
# 3                                  [cot_mm_positioning]
# 4                  [cpc_soil_z, inseason_weather_dense]
# ..                                                  ...
# 37                                                   []
# 38                                                   []
# 39                                                   []
# 40                                 [wap_nonUS_revision]
# 41                             [wasde_direct_revisions]
#
#    column_coverage_status  candidate_classification_verified  \
# 0            not_assessed                              False
# 1            not_assessed                              False
# 2            not_assessed                              False
# 3            not_assessed                              False
# 4            not_assessed                              False
# ..                    ...                                ...
# 37         not_applicable                              False
# 38         not_applicable                              False
# 39         not_applicable                              False
# 40           not_assessed                              False
# 41           not_assessed                              False
#
#    feature_disposition  existing_family_count exactness
# 0     candidate_source                      1     exact
# 1     candidate_source                      3     exact
# 2     candidate_source                      1     exact
# 3     candidate_source                      1     exact
# 4     candidate_source                      2     exact
# ..                 ...                    ...       ...
# 37             blocked                      0     exact
# 38             blocked                      0     exact
# 39             blocked                      0     exact
# 40    candidate_source                      1     exact
# 41    candidate_source                      1     exact
#
# [42 rows x 8 columns]

# %% [markdown]
# ## Review-only candidate catalog
#
# All candidates are unpromoted review records with evidence, counter-evidence, PIT rules, and independent review status.

# %%
candidate_rows = []
for table, block in sorted(CATALOG["tables"].items()):
    candidate_rows.extend(block.get("candidates", []))
candidates = pd.DataFrame(candidate_rows)
if candidates.empty:
    display(pd.DataFrame([{"status": "No campaign candidates", "exactness": "exact"}]))
else:
    candidates["exactness"] = "exact"
    display(candidates[[c for c in ["candidate_id","source_table","classification","computation_primitive","readiness","review_status","evidence"] if c in candidates]].head(100))
    by_class = candidates.classification.value_counts().sort_index()
    ax = by_class.plot.bar(color="#356AA0", figsize=(7,3), legend=False)
    ax.set_title(f"Review-only candidates by class — n={len(candidates)} — exact")
    ax.set_ylabel("Candidates"); plt.xticks(rotation=25); plt.show()
assert not any(c.get("source_table") == "silver_model_predictions" for c in candidate_rows)
# Out:
#                                                              candidate_id  \
# 0               eda:silver_ams_cotton_quality:percent_tenderable:change_1
# 1                  eda:silver_ams_cotton_quality:percent_tenderable:lag_1
# 2                  eda:silver_ams_cotton_quality:percent_tenderable:level
# 3       eda:silver_ams_cotton_quality:percent_tenderable:robust_deviation
# 4         eda:silver_ams_cotton_quality:percent_tenderable:rolling_mean_3
# ..                                                                    ...
# 95  eda:silver_fnc_colombia_monthly:production_bags_60kg:robust_deviation
# 96    eda:silver_fnc_colombia_monthly:production_bags_60kg:rolling_mean_3
# 97                               eda:silver_food_cpi:cpi_yoy_pct:change_1
# 98                                  eda:silver_food_cpi:cpi_yoy_pct:lag_1
# 99                                  eda:silver_food_cpi:cpi_yoy_pct:level
#
#                    source_table classification computation_primitive  \
# 0     silver_ams_cotton_quality            new            difference
# 1     silver_ams_cotton_quality            new                   lag
# 2     silver_ams_cotton_quality            new              identity
# 3     silver_ams_cotton_quality            new      rolling_robust_z
# 4     silver_ams_cotton_quality            new          rolling_mean
# ..                          ...            ...                   ...
# 95  silver_fnc_colombia_monthly            new      rolling_robust_z
# 96  silver_fnc_colombia_monthly            new          rolling_mean
# 97              silver_food_cpi            new            difference
# 98              silver_food_cpi            new                   lag
# 99              silver_food_cpi            new              identity
#
#                      readiness review_status  \
# 0   needs_contract_or_data_fix    unreviewed
# 1   needs_contract_or_data_fix    unreviewed
# 2   needs_contract_or_data_fix    unreviewed
# 3   needs_contract_or_data_fix    unreviewed
# 4   needs_contract_or_data_fix    unreviewed
# ..                         ...           ...
# 95  needs_contract_or_data_fix    unreviewed
# 96  needs_contract_or_data_fix    unreviewed
# 97  needs_contract_or_data_fix    unreviewed
# 98  needs_contract_or_data_fix    unreviewed
# 99  needs_contract_or_data_fix    unreviewed
#
#                                                                                                evidence
# 0   [metric:distributions.numeric_distributions.percent_tenderable, cell:distributions-output, metri...
# 1   [metric:distributions.numeric_distributions.percent_tenderable, cell:distributions-output, metri...
# 2   [metric:distributions.numeric_distributions.percent_tenderable, cell:distributions-output, metri...
# 3            [metric:distributions.numeric_distributions.percent_tenderable, cell:distributions-output]
# 4   [metric:distributions.numeric_distributions.percent_tenderable, cell:distributions-output, metri...
# ..                                                                                                  ...
# 95         [metric:distributions.numeric_distributions.production_bags_60kg, cell:distributions-output]
# 96  [metric:distributions.numeric_distributions.production_bags_60kg, cell:distributions-output, met...
# 97  [metric:distributions.numeric_distributions.cpi_yoy_pct, cell:distributions-output, metric:missi...
# 98  [metric:distributions.numeric_distributions.cpi_yoy_pct, cell:distributions-output, metric:missi...
# 99  [metric:distributions.numeric_distributions.cpi_yoy_pct, cell:distributions-output, metric:missi...
#
# [100 rows x 7 columns]

# %% [markdown]
# ## Cross-source work orders
#
# Cross-source repairs and semantic decisions are prioritized from each dossier's findings.

# %%
work = READINESS.get("work_orders", [])
work_frame = pd.DataFrame(work)
if not work_frame.empty and "exactness" not in work_frame:
    work_frame["exactness"] = work_frame.table_name.map(ROWS.set_index("table_name").analysis_exactness) if "table_name" in work_frame else "exact"
display(work_frame.head(200) if not work_frame.empty else pd.DataFrame([{"status":"No work order emitted", "exactness": "exact"}]))
# Out:
#                                         code  \
# 0                                EDA-PIT-002
# 1                      EDA-SEMANTIC-UNIT-001
# 2             EDA-MAPPING-AMS_COTTON_QUALITY
# 3    EDA-FEATURE-COVERAGE-AMS_COTTON_QUALITY
# 4                EDA-CANDIDATE-PREREQUISITES
# ..                                       ...
# 166              EDA-CANDIDATE-PREREQUISITES
# 167                             EDA-NULL-001
# 168                        EDA-MAPPING-WASDE
# 169               EDA-FEATURE-COVERAGE-WASDE
# 170              EDA-CANDIDATE-PREREQUISITES
#
#                                                                                                 evidence  \
# 0    [pit_leakage.knowledge_time_readiness, pit_leakage.knowledge_date_column, pit_leakage.publicatio...
# 1                                                       [overlay.units, schema_contract.column_contract]
# 2                                                                            [spec.semantic_work_orders]
# 3                                                                            [spec.semantic_work_orders]
# 4                                                                         [feature_candidates.readiness]
# ..                                                                                                   ...
# 166                                                                       [feature_candidates.readiness]
# 167                                                    [missingness_validity.required_complete_row_rate]
# 168                                                                          [spec.semantic_work_orders]
# 169                                                                          [spec.semantic_work_orders]
# 170                                                                       [feature_candidates.readiness]
#
#     exactness                                                    finding  \
# 0       exact                  Feature availability time is not governed
# 1       exact                     Feature-bearing units are not governed
# 2       exact  Declare a governed semantic mapping before pairwise joins
# 3       exact      Verify production feature column/computation coverage
# 4       exact                  Candidate prerequisites remain unresolved
# ..        ...                                                        ...
# 166     exact                  Candidate prerequisites remain unresolved
# 167     exact                              Required fields contain nulls
# 168     exact  Declare a governed semantic mapping before pairwise joins
# 169     exact      Verify production feature column/computation coverage
# 170     exact                  Candidate prerequisites remain unresolved
#
#     severity                    table_name  \
# 0       high     silver_ams_cotton_quality
# 1       high     silver_ams_cotton_quality
# 2       high     silver_ams_cotton_quality
# 3     medium     silver_ams_cotton_quality
# 4       high     silver_ams_cotton_quality
# ..       ...                           ...
# 166     high  silver_wap_table01_revisions
# 167     high                  silver_wasde
# 168     high                  silver_wasde
# 169   medium                  silver_wasde
# 170     high                  silver_wasde
#
#                                                                                               work_order
# 0    Declare and validate a fully parseable knowledge-time column, or govern a non-negative publicati...
# 1    Govern source units and conversion policy for every feature-bearing value column before prototyp...
# 2    Register the canonical mapping and key grain, then measure raw/mapped coverage, overlap, and row...
# 3    Map each table-level family to exact source columns and computation kinds before calling any EDA...
# 4         Resolve PIT, unit, mapping, and semantic prerequisites for 10 candidate(s) before prototyping.
# ..                                                                                                   ...
# 166        Resolve PIT, unit, mapping, and semantic prerequisites for 3 candidate(s) before prototyping.
# 167                              Segment structural nulls from writer defects and codify the valid rule.
# 168  Register the canonical mapping and key grain, then measure raw/mapped coverage, overlap, and row...
# 169  Map each table-level family to exact source columns and computation kinds before calling any EDA...
# 170        Resolve PIT, unit, mapping, and semantic prerequisites for 4 candidate(s) before prototyping.
#
# [171 rows x 7 columns]

# %% [markdown]
# ## Reproducibility and safety assertions
#
# Campaign, registry, code, config, image, and artifact hashes plus hard scope assertions make the readout auditable.

# %%
scope = READINESS["analysis_scope"]
assert scope["legacy_gold_read"] is False and scope["model_ready_read"] is False
assert scope["target_aware_analysis"] is False and scope["gold_contracts_included"] == 0
assert sorted(SPECS) == sorted(READINESS["expected_tables"])
model_row = ROWS.loc[ROWS.table_name.eq("silver_model_predictions")].iloc[0]
assert model_row.disposition == "excluded_leakage" and int(model_row.candidate_count) == 0
display(pd.DataFrame([{"assertion":"42/42 exact registry set", "passed":True, "exactness":"exact"},
                      {"assertion":"no Gold/model-ready/target analysis", "passed":True, "exactness":"exact"},
                      {"assertion":"model predictions quarantined with zero candidates", "passed":True, "exactness":"exact"},
                      {"assertion":"production feature configuration unchanged", "passed":True, "exactness":"exact"}]))
# Out:
#                                             assertion  passed exactness
# 0                            42/42 exact registry set    True     exact
# 1                 no Gold/model-ready/target analysis    True     exact
# 2  model predictions quarantined with zero candidates    True     exact
# 3          production feature configuration unchanged    True     exact
